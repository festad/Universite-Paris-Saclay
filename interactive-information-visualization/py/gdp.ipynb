# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# Locating the file
HOME = Path() / '../'
WBANK = HOME / 'food-waste-dataset' / 'worldbank'
FAO = HOME / 'food-waste-dataset' / 'fao'

pop_emi_df = pd.read_csv(WBANK / 'population_emission.csv', encoding='latin-1')

# %%
pop_emi_df.columns
# Out:
# Index(['country', 'year', 'population', 'emission'], dtype='object')

# %%
gdp_df = pd.read_csv(WBANK/'gdp'/'gdp-untidy.csv')

# %%
gdp_df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#        'Unnamed: 66'],
#       dtype='object')

# %%
gdp_df.rename(index=str, columns={'Country Name':'country'}, inplace=True)

# %%
gdp_df.columns[34:64]
# Out:
# Index(['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019'],
#       dtype='object')

# %%
filt_gdp_df = gdp_df.loc[:, ['country'] + [str(i) for i in range(1990, 2020)]]

# %%
filt_gdp_df
# Out:
#                          country          1990          1991          1992  \
# 0                          Aruba  7.648045e+08  8.720670e+08  9.586592e+08
# 1    Africa Eastern and Southern  2.532267e+11  2.734057e+11  2.382580e+11
# 2                    Afghanistan           NaN           NaN           NaN
# 3     Africa Western and Central  1.218021e+11  1.174571e+11  1.182823e+11
# 4                         Angola  1.122876e+10  1.060378e+10  8.307811e+09
# ..                           ...           ...           ...           ...
# 261                       Kosovo           NaN           NaN           NaN
# 262                  Yemen, Rep.  5.647119e+09  5.930370e+09  6.463650e+09
# 263                 South Africa  1.260481e+11  1.352044e+11  1.469569e+11
# 264                       Zambia  3.285217e+09  3.378882e+09  3.181922e+09
# 265                     Zimbabwe  8.783817e+09  8.641482e+09  6.751472e+09
#
# ...

# %%
filt_gdp_df = filt_gdp_df.melt('country', var_name='year', value_name='gdp')
filt_gdp_df['year'] = filt_gdp_df['year'].astype(int)
filt_gdp_df
# Out:
#                           country  year           gdp
# 0                           Aruba  1990  7.648045e+08
# 1     Africa Eastern and Southern  1990  2.532267e+11
# 2                     Afghanistan  1990           NaN
# 3      Africa Western and Central  1990  1.218021e+11
# 4                          Angola  1990  1.122876e+10
# ...                           ...   ...           ...
# 7975                       Kosovo  2019  7.899879e+09
# 7976                  Yemen, Rep.  2019           NaN
# 7977                 South Africa  2019  3.885320e+11
# 7978                       Zambia  2019  2.330867e+10
# 7979                     Zimbabwe  2019  2.183223e+10
#
# [7980 rows x 3 columns]

# %%
filt_gdp_df.to_csv(WBANK / 'gdp' / 'gdp.csv', index=False)
