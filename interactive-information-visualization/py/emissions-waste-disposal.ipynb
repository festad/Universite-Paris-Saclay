# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# Locating the file
HOME = Path() / '../'
FAO = HOME / 'food-waste-dataset' / 'fao'
DATA = FAO / 'emissions-waste-disposal' / 'emissions-waste-disposal.csv'
df = pd.read_csv(DATA, encoding='latin-1')

# %%
# Variables
for c in df.columns:
    print('->', c)
# Out:
# -> Area Code
# -> Area Code (M49)
# -> Area
# -> Item Code
# -> Item
# -> Element Code
# -> Element
# -> Year Code
# -> Year
# -> Unit
# -> Value
# -> Flag

# %%
# Reading the countries
countries = sorted(df['Area'].unique())
print(f'There are {len(countries)} different countries in the dataset:')
for c in countries:
    print('->', c)
# Out:
# There are 271 different countries in the dataset:
# -> Afghanistan
# -> Africa
# -> Albania
# -> Algeria
# -> American Samoa
# -> Americas
# -> Andorra
# -> Angola
# -> Annex I countries
# -> Antigua and Barbuda
# -> Argentina
# -> Armenia
# -> Aruba
# -> Asia
# -> Australia
# -> Australia and New Zealand
# -> Austria
# -> Azerbaijan
# -> Bahamas
# -> Bahrain
# -> Bangladesh
# -> Barbados
# -> Belarus
# -> Belgium
# -> Belgium-Luxembourg
# -> Belize
# -> Benin
# -> Bermuda
# -> Bhutan
# -> Bolivia (Plurinational State of)
# -> Bosnia and Herzegovina
# -> Botswana
# -> Brazil
# -> British Virgin Islands
# -> Brunei Darussalam
# -> Bulgaria
# -> Burkina Faso
# -> Burundi
# -> Cabo Verde
# -> Cambodia
# -> Cameroon
# -> Canada
# -> Caribbean
# -> Cayman Islands
# -> Central African Republic
# -> Central America
# -> Central Asia
# -> Chad
# -> Chile
# -> China
# -> China, Hong Kong SAR
# -> China, Macao SAR
# -> China, mainland
# -> Colombia
# -> Comoros
# -> Congo
# -> Cook Islands
# -> Costa Rica
# -> Croatia
# -> Cuba
# -> Cyprus
# -> Czechia
# -> Czechoslovakia
# -> Côte d'Ivoire
# -> Democratic People's Republic of Korea
# -> Democratic Republic of the Congo
# -> Denmark
# -> Djibouti
# -> Dominica
# -> Dominican Republic
# -> Eastern Africa
# -> Eastern Asia
# -> Eastern Europe
# -> Ecuador
# -> Egypt
# -> El Salvador
# -> Equatorial Guinea
# -> Eritrea
# -> Estonia
# -> Eswatini
# -> Ethiopia
# -> Ethiopia PDR
# -> Europe
# -> European Union (27)
# -> Falkland Islands (Malvinas)
# -> Faroe Islands
# -> Fiji
# -> Finland
# -> France
# -> French Guyana
# -> French Polynesia
# -> Gabon
# -> Gambia
# -> Georgia
# -> Germany
# -> Ghana
# -> Gibraltar
# -> Greece
# -> Greenland
# -> Grenada
# -> Guadeloupe
# -> Guam
# -> Guatemala
# -> Guinea
# -> Guinea-Bissau
# -> Guyana
# -> Haiti
# -> Honduras
# -> Hungary
# -> Iceland
# -> India
# -> Indonesia
# -> Iran (Islamic Republic of)
# -> Iraq
# -> Ireland
# -> Isle of Man
# -> Israel
# -> Italy
# -> Jamaica
# -> Japan
# -> Jordan
# -> Kazakhstan
# -> Kenya
# -> Kiribati
# -> Kuwait
# -> Kyrgyzstan
# -> Land Locked Developing Countries
# -> Lao People's Democratic Republic
# -> Latvia
# -> Least Developed Countries
# -> Lebanon
# -> Lesotho
# -> Liberia
# -> Libya
# -> Liechtenstein
# -> Lithuania
# -> Low Income Food Deficit Countries
# -> Luxembourg
# -> Madagascar
# -> Malawi
# -> Malaysia
# -> Maldives
# -> Mali
# -> Malta
# -> Marshall Islands
# -> Martinique
# -> Mauritania
# -> Mauritius
# -> Melanesia
# -> Mexico
# -> Micronesia
# -> Micronesia (Federated States of)
# -> Middle Africa
# -> Monaco
# -> Mongolia
# -> Montenegro
# -> Montserrat
# -> Morocco
# -> Mozambique
# -> Myanmar
# -> Namibia
# -> Nauru
# -> Nepal
# -> Net Food Importing Developing Countries
# -> Netherlands
# -> Netherlands Antilles (former)
# -> New Caledonia
# -> New Zealand
# -> Nicaragua
# -> Niger
# -> Nigeria
# -> Niue
# -> Non-Annex I countries
# -> North Macedonia
# -> Northern Africa
# -> Northern America
# -> Northern Europe
# -> Northern Mariana Islands
# -> Norway
# -> OECD
# -> Oceania
# -> Oman
# -> Pacific Islands Trust Territory
# -> Pakistan
# -> Palau
# -> Panama
# -> Papua New Guinea
# -> Paraguay
# -> Peru
# -> Philippines
# -> Poland
# -> Polynesia
# -> Portugal
# -> Puerto Rico
# -> Qatar
# -> Republic of Korea
# -> Republic of Moldova
# -> Romania
# -> Russian Federation
# -> Rwanda
# -> Réunion
# -> Saint Helena, Ascension and Tristan da Cunha
# -> Saint Kitts and Nevis
# -> Saint Lucia
# -> Saint Pierre and Miquelon
# -> Saint Vincent and the Grenadines
# -> Samoa
# -> San Marino
# -> Sao Tome and Principe
# -> Saudi Arabia
# -> Senegal
# -> Serbia
# -> Serbia and Montenegro
# -> Seychelles
# -> Sierra Leone
# -> Singapore
# -> Slovakia
# -> Slovenia
# -> Small Island Developing States
# -> Solomon Islands
# -> Somalia
# -> South Africa
# -> South America
# -> South Sudan
# -> South-eastern Asia
# -> Southern Africa
# -> Southern Asia
# -> Southern Europe
# -> Spain
# -> Sri Lanka
# -> Sudan
# -> Sudan (former)
# -> Suriname
# -> Sweden
# -> Switzerland
# -> Syrian Arab Republic
# -> Tajikistan
# -> Thailand
# -> Timor-Leste
# -> Togo
# -> Tokelau
# -> Tonga
# -> Trinidad and Tobago
# -> Tunisia
# -> Turkmenistan
# -> Turks and Caicos Islands
# -> Tuvalu
# -> Türkiye
# -> USSR
# -> Uganda
# -> Ukraine
# -> United Arab Emirates
# -> United Kingdom of Great Britain and Northern Ireland
# -> United Republic of Tanzania
# -> United States Virgin Islands
# -> United States of America
# -> Uruguay
# -> Uzbekistan
# -> Vanuatu
# -> Venezuela (Bolivarian Republic of)
# -> Viet Nam
# -> Wallis and Futuna Islands
# -> Western Africa
# -> Western Asia
# -> Western Europe
# -> Western Sahara
# -> World
# -> Yemen
# -> Yugoslav SFR
# -> Zambia
# -> Zimbabwe

# %%
# Range of years available
df['Year'].unique()
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019])

# %%
df['Item'].unique()
# Out:
# array(['Domestic wastewater', 'Incineration', 'Industrial wastewater',
#        'Solid food waste', 'Waste - agri-food systems'], dtype=object)

# %%
df['Element'].unique()
# Out:
# array(['Emissions (CH4)', 'Emissions (N2O)', 'Emissions (CO2)'],
#       dtype=object)

# %%
#The only flag is 'E', that means 'estimated values'
df['Flag'].unique()
# Out:
# array(['E'], dtype=object)

# %%
df
# Out:
#        Area Code Area Code (M49)         Area  Item Code  \
# 0              2            '004  Afghanistan       6988
# 1              2            '004  Afghanistan       6988
# 2              2            '004  Afghanistan       6988
# 3              2            '004  Afghanistan       6988
# 4              2            '004  Afghanistan       6988
# ...          ...             ...          ...        ...
# 67259       5873            '198         OECD       6991
# 67260       5873            '198         OECD       6991
# 67261       5873            '198         OECD       6991
# 67262       5873            '198         OECD       6991
# 67263       5873            '198         OECD       6991
#
#                             Item  Element Code          Element  Year Code  \
# 0            Domestic wastewater          7225  Emissions (CH4)       1990
# 1            Domestic wastewater          7225  Emissions (CH4)       1991
# 2            Domestic wastewater          7225  Emissions (CH4)       1992
# 3            Domestic wastewater          7225  Emissions (CH4)       1993
# 4            Domestic wastewater          7225  Emissions (CH4)       1994
# ...                          ...           ...              ...        ...
# 67259  Waste - agri-food systems          7230  Emissions (N2O)       2015
# 67260  Waste - agri-food systems          7230  Emissions (N2O)       2016
# 67261  Waste - agri-food systems          7230  Emissions (N2O)       2017
# 67262  Waste - agri-food systems          7230  Emissions (N2O)       2018
# 67263  Waste - agri-food systems          7230  Emissions (N2O)       2019
#
#        Year        Unit      Value Flag
# 0      1990  kilotonnes  15.855902    E
# 1      1991  kilotonnes  16.988608    E
# 2      1992  kilotonnes  18.504317    E
# 3      1993  kilotonnes  20.204656    E
# 4      1994  kilotonnes  21.813107    E
# ...     ...         ...        ...  ...
# 67259  2015  kilotonnes  62.348709    E
# 67260  2016  kilotonnes  63.962387    E
# 67261  2017  kilotonnes  66.273217    E
# 67262  2018  kilotonnes  68.439822    E
# 67263  2019  kilotonnes  70.461855    E
#
# [67264 rows x 12 columns]

# %%
countries = ['France', 'Finland', 'India', 'Italy', 'China', 'United States of America', 'Japan']

fr_domwaste_emiss = df.loc[(df['Area'].isin(countries))
                         & (df['Item'] == 'Domestic wastewater')]

ch4_df = fr_domwaste_emiss.loc[fr_domwaste_emiss['Element'] == 'Emissions (CH4)']
n2o_df = fr_domwaste_emiss.loc[fr_domwaste_emiss['Element'] == 'Emissions (N2O)']


# print(ch4_df['Unit'].unique())
# The unit of measure is 'kilotonnes'

ch4_df = ch4_df[['Year', 'Area', 'Value']]
n2o_df = n2o_df[['Year', 'Area', 'Value']]

ch4_df = ch4_df.pivot(index='Year', columns='Area', values='Value')
n2o_df = n2o_df.pivot(index='Year', columns='Area', values='Value')

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(15, 7))

ch4_df.plot(ax=ax1, title='CH4')
ax1.set_xlabel('Year')
ax1.set_ylabel('kilotonnes')

n2o_df.plot(ax=ax2, title='N2O')
ax2.set_xlabel('Year')
ax2.set_ylabel('kilotonnes')

plt.show()


# The plot shows the prevalence of emissions in China and India.

# %%
# In the plot above United States are not visible in the CH4 plot,
# in fact there are no data about CH4, only about N2O.
us_df = df.loc[(df['Area'] == 'United States of America') & (df['Item'] == 'Domestic wastewater')]
print(us_df['Element'].unique())
# Out:
# ['Emissions (N2O)']

# %%
df.loc[(df['Item'] == 'Solid food waste') & (df['Element'] == 'Emissions (CH4)') & (df['Area'] == 'France')]
# Out:
#        Area Code Area Code (M49)    Area  Item Code              Item  \
# 18939         68            '250  France       6987  Solid food waste
# 18940         68            '250  France       6987  Solid food waste
# 18941         68            '250  France       6987  Solid food waste
# 18942         68            '250  France       6987  Solid food waste
# 18943         68            '250  France       6987  Solid food waste
# 18944         68            '250  France       6987  Solid food waste
# 18945         68            '250  France       6987  Solid food waste
# 18946         68            '250  France       6987  Solid food waste
# 18947         68            '250  France       6987  Solid food waste
# 18948         68            '250  France       6987  Solid food waste
# 18949         68            '250  France       6987  Solid food waste
# 18950         68            '250  France       6987  Solid food waste
# 18951         68            '250  France       6987  Solid food waste
# 18952         68            '250  France       6987  Solid food waste
# 18953         68            '250  France       6987  Solid food waste
# 18954         68            '250  France       6987  Solid food waste
# 18955         68            '250  France       6987  Solid food waste
# 18956         68            '250  France       6987  Solid food waste
# 18957         68            '250  France       6987  Solid food waste
# 18958         68            '250  France       6987  Solid food waste
# 18959         68            '250  France       6987  Solid food waste
# 18960         68            '250  France       6987  Solid food waste
# 18961         68            '250  France       6987  Solid food waste
# 18962         68            '250  France       6987  Solid food waste
# 18963         68            '250  France       6987  Solid food waste
# 18964         68            '250  France       6987  Solid food waste
# 18965         68            '250  France       6987  Solid food waste
# 18966         68            '250  France       6987  Solid food waste
# 18967         68            '250  France       6987  Solid food waste
# 18968         68            '250  France       6987  Solid food waste
#
#        Element Code          Element  Year Code  Year        Unit      Value  \
# 18939          7225  Emissions (CH4)       1990  1990  kilotonnes  66.575628
# 18940          7225  Emissions (CH4)       1991  1991  kilotonnes  68.414611
# 18941          7225  Emissions (CH4)       1992  1992  kilotonnes  69.993005
# 18942          7225  Emissions (CH4)       1993  1993  kilotonnes  71.272160
# 18943          7225  Emissions (CH4)       1994  1994  kilotonnes  72.363761
# 18944          7225  Emissions (CH4)       1995  1995  kilotonnes  73.339069
# 18945          7225  Emissions (CH4)       1996  1996  kilotonnes  74.146200
# 18946          7225  Emissions (CH4)       1997  1997  kilotonnes  74.766431
# 18947          7225  Emissions (CH4)       1998  1998  kilotonnes  75.302599
# 18948          7225  Emissions (CH4)       1999  1999  kilotonnes  75.743653
# 18949          7225  Emissions (CH4)       2000  2000  kilotonnes  76.065389
# 18950          7225  Emissions (CH4)       2001  2001  kilotonnes  76.340364
# 18951          7225  Emissions (CH4)       2002  2002  kilotonnes  76.612009
# 18952          7225  Emissions (CH4)       2003  2003  kilotonnes  76.938632
# 18953          7225  Emissions (CH4)       2004  2004  kilotonnes  77.272988
# 18954          7225  Emissions (CH4)       2005  2005  kilotonnes  77.564046
# 18955          7225  Emissions (CH4)       2006  2006  kilotonnes  77.832306
# 18956          7225  Emissions (CH4)       2007  2007  kilotonnes  78.122354
# 18957          7225  Emissions (CH4)       2008  2008  kilotonnes  78.407321
# 18958          7225  Emissions (CH4)       2009  2009  kilotonnes  78.599595
# 18959          7225  Emissions (CH4)       2010  2010  kilotonnes  78.751756
# 18960          7225  Emissions (CH4)       2011  2011  kilotonnes  78.919277
# 18961          7225  Emissions (CH4)       2012  2012  kilotonnes  79.022649
# 18962          7225  Emissions (CH4)       2013  2013  kilotonnes  79.134432
# 18963          7225  Emissions (CH4)       2014  2014  kilotonnes  79.233538
# 18964          7225  Emissions (CH4)       2015  2015  kilotonnes  79.235729
# 18965          7225  Emissions (CH4)       2016  2016  kilotonnes  79.250066
# 18966          7225  Emissions (CH4)       2017  2017  kilotonnes  79.285840
# 18967          7225  Emissions (CH4)       2018  2018  kilotonnes  79.350587
# 18968          7225  Emissions (CH4)       2019  2019  kilotonnes  79.390471
#
#       Flag
# 18939    E
# 18940    E
# 18941    E
# 18942    E
# 18943    E
# 18944    E
# 18945    E
# 18946    E
# 18947    E
# 18948    E
# 18949    E
# 18950    E
# 18951    E
# 18952    E
# 18953    E
# 18954    E
# 18955    E
# 18956    E
# 18957    E
# 18958    E
# 18959    E
# 18960    E
# 18961    E
# 18962    E
# 18963    E
# 18964    E
# 18965    E
# 18966    E
# 18967    E
# 18968    E

# %%
df.loc[(df['Item'] == 'Waste - agri-food systems') & (df['Element'] == 'Emissions (CH4)') & (df['Area'] == 'France') & (df['Year'] == 2019)]
# Out:
#        Area Code Area Code (M49)    Area  Item Code  \
# 19028         68            '250  France       6991
#
#                             Item  Element Code          Element  Year Code  \
# 19028  Waste - agri-food systems          7225  Emissions (CH4)       2019
#
#        Year        Unit       Value Flag
# 19028  2019  kilotonnes  236.516853    E

# %%
df.loc[(df['Item'] == 'Solid food waste') & (df['Element'] == 'Emissions (CH4)') & (df['Area'] == 'France') & (df['Year'] == 2019)]
# Out:
#        Area Code Area Code (M49)    Area  Item Code              Item  \
# 18968         68            '250  France       6987  Solid food waste
#
#        Element Code          Element  Year Code  Year        Unit      Value  \
# 18968          7225  Emissions (CH4)       2019  2019  kilotonnes  79.390471
#
#       Flag
# 18968    E
